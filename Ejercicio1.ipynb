# %% [markdown]
# <a href="https://colab.research.google.com/github/martinezroxany92-del/ejercicios_de_python/blob/main/Ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tipos de Datos
# Int - float - str - bolean

# %%
nombre = input ("¿Cual es tu nombre? ")
edad = int(input("¿Cual es tu edad? "))
print (f"Hola {nombre} tienes {edad} años")
# Out:
# ¿Cual es tu nombre?Roxany
# ¿Cual es tu edad?30
# Hola Roxany tienes 30 años

# %%
#Definimos una variable
def saludar (nombre):
  print (f"Hola {nombre} bienvenid@ al taller de python")
saludar (nombre)
# Out:
# Hola Roxany bienvenid@ al taller de python

# %%
def mayor_de_edad(edad):
    if edad >= 18:
        print("Eres mayor de edad")
    elif edad <= 11:
        print("Eres un niño pequeño")
    else:
        print("Eres menor de edad")


edad = int(input("¿Cuántos años tienes? "))
mayor_de_edad(edad)
# Out:
# ¿Cuántos años tienes? 30
# Eres mayor de edad
